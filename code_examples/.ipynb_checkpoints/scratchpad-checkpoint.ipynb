# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
f_ = sin(x)*sin(y)/(x*y)
f_f = Function('f')(x)
Eq(f_f, f_)
# Out:
#        sin(x)⋅sin(y)
# f(x) = ─────────────
#             x⋅y

# %%
from sympy import *
init_printing()
import numpy as np
from scipy import interpolate

x, y = symbols('x y')
f = sin(x)*sin(y)/(x*y)
f = lambdify((x, y), f)

xs, ys = np.mgrid[-np.pi:np.pi:31j, -np.pi:np.pi:31j]
zs = f(xs, ys)
# Out:
# <string>:2: RuntimeWarning: invalid value encountered in true_divide

# %%
xx, yy = np.meshgrid(np.arange(0, zs.shape[1]),
                     np.arange(0, zs.shape[0]))

#mask invalid values
zs_masked = np.ma.masked_invalid(zs)

# %%
#get only the valid values
x1 = xx[~zs_masked.mask]
y1 = yy[~zs_masked.mask]

# %%
zs_interp = zs_masked[~zs_masked.mask]

# %%
GD1 = interpolate.griddata((x1, y1), zs_interp.ravel(),
                          (xx, yy),
                             method='cubic')

# %%
# original data

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(X=xs, Y=ys, Z=zs)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# interpolated data

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(X=xs, Y=ys, Z=GD1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import random
hash1 = random.getrandbits(256)

# %%
hash1
# Out:
# 96583949442227879066523833218924226941726975653546828144093874593200914474025

# %%
import json
import numpy as np

r = {'is_claimed': 'True', 'rating': np.array([1,2,3]).tolist()}
r = json.dumps(r)
loaded_r = json.loads(r)
loaded_r['rating']
# Out:
# [1, 2, 3]

# %%
# %%timeit
random.getrandbits(32)
# Out:
# 400 ns ± 53.7 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
import pyqtgraph.opengl as gl

# %%
help(gl.GLSurfacePlotItem)
# Out:
# Help on class GLSurfacePlotItem in module pyqtgraph.opengl.items.GLSurfacePlotItem:
#
# class GLSurfacePlotItem(pyqtgraph.opengl.items.GLMeshItem.GLMeshItem)
#  |  **Bases:** :class:`GLMeshItem <pyqtgraph.opengl.GLMeshItem>`
#  |
#  |  Displays a surface plot on a regular x,y grid
#  |
#  |  Method resolution order:
#  |      GLSurfacePlotItem
#  |      pyqtgraph.opengl.items.GLMeshItem.GLMeshItem
#  |      pyqtgraph.opengl.GLGraphicsItem.GLGraphicsItem
#  |      PyQt5.QtCore.QObject
#  |      sip.wrapper
#  |      sip.simplewrapper
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, x=None, y=None, z=None, colors=None, **kwds)
#  |      The x, y, z, and colors arguments are passed to setData().
#  |      All other keyword arguments are passed to GLMeshItem.__init__().
#  |
#  |  generateFaces(self)
#  |
#  |  setData(self, x=None, y=None, z=None, colors=None)
#  |      Update the data in this surface plot.
#  |
# ...

# %%
np.mgrid[-5:5:10j, -5:5:20j][1].shape
# Out:
# (10, 20)

# %%
zs.shape
# Out:
# (31, 31)

# %%
len(GD1.ravel())
# Out:
# 961

# %%
# integer arrays for indexing
x_indx, y_indx = np.meshgrid(np.arange(0, zs.shape[1]),
                             np.arange(0, zs.shape[0]))

# mask all invalid values
zs_masked = np.ma.masked_invalid(zs)

# retrieve the valid, non-Nan, defined values
valid_xs = x_indx[~zs_masked.mask]
valid_ys = y_indx[~zs_masked.mask]
valid_zs = zs_masked[~zs_masked.mask]

# generate interpolated array of z-values
zs_interp = interpolate.griddata((valid_xs, valid_ys), valid_zs.ravel(),
                                 (x_indx, y_indx), method='cubic')

# finally, plot the data 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(X=xs, Y=ys, Z=zs_interp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-103-5ecedc391fab> in <module>
#      10 # generate interpolated array of z-values
#      11 zs_interp = interpolate.griddata((xs, ys), GD1.ravel(),
# ---> 12                                  (x_indx, y_indx), method='cubic')
#      13
#      14 # finally, plot the data
#
# ~\Miniconda3\envs\qtdev\lib\site-packages\scipy\interpolate\ndgriddata.py in griddata(points, values, xi, method, fill_value, rescale)
#     224     elif method == 'cubic' and ndim == 2:
#     225         ip = CloughTocher2DInterpolator(points, values, fill_value=fill_value,
# --> 226                                         rescale=rescale)
#     227         return ip(xi)
#     228     else:
#
# interpnd.pyx in scipy.interpolate.interpnd.CloughTocher2DInterpolator.__init__()
#
# ...

# %%
from PyQt5.QtWidgets import (QApplication, QGridLayout, QLayout, QLineEdit,
                             QSizePolicy, QToolButton, QWidget, QLabel, QCheckBox,
                             QTableWidget, QTableWidgetItem, QToolBar, QHBoxLayout)

# %%
help(QGridLayout)
# Out:
# Help on class QGridLayout in module PyQt5.QtWidgets:
#
# class QGridLayout(QLayout)
#  |  QGridLayout(QWidget)
#  |  QGridLayout()
#  |
#  |  Method resolution order:
#  |      QGridLayout
#  |      QLayout
#  |      PyQt5.QtCore.QObject
#  |      QLayoutItem
#  |      sip.wrapper
#  |      sip.simplewrapper
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  addChildLayout(...)
#  |
#  |  addChildWidget(...)
#  |
#  |  addItem(...)
#  |      addItem(self, QLayoutItem, int, int, rowSpan: int = 1, columnSpan: int = 1, alignment: Union[Qt.Alignment, Qt.AlignmentFlag] = Qt.Alignment())
#  |      addItem(self, QLayoutItem)
#  |
#  |  addLayout(...)
#  |      addLayout(self, QLayout, int, int, alignment: Union[Qt.Alignment, Qt.AlignmentFlag] = Qt.Alignment())
#  |      addLayout(self, QLayout, int, int, int, int, alignment: Union[Qt.Alignment, Qt.AlignmentFlag] = Qt.Alignment())
#  |
#  |  addWidget(...)
#  |      addWidget(self, QWidget)
# ...

# %%
help(QTableWidgetItem)
# Out:
# Help on class QTableWidgetItem in module PyQt5.QtWidgets:
#
# class QTableWidgetItem(sip.wrapper)
#  |  QTableWidgetItem(type: int = QTableWidgetItem.Type)
#  |  QTableWidgetItem(str, type: int = QTableWidgetItem.Type)
#  |  QTableWidgetItem(QIcon, str, type: int = QTableWidgetItem.Type)
#  |  QTableWidgetItem(QTableWidgetItem)
#  |
#  |  Method resolution order:
#  |      QTableWidgetItem
#  |      sip.wrapper
#  |      sip.simplewrapper
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  background(...)
#  |      background(self) -> QBrush
#  |
#  |  checkState(...)
# ...

# %%
help(QTableWidget)
# Out:
# Help on class QTableWidget in module PyQt5.QtWidgets:
#
# class QTableWidget(QTableView)
#  |  QTableWidget(parent: QWidget = None)
#  |  QTableWidget(int, int, parent: QWidget = None)
#  |
#  |  Method resolution order:
#  |      QTableWidget
#  |      QTableView
#  |      QAbstractItemView
#  |      QAbstractScrollArea
#  |      QFrame
#  |      QWidget
#  |      PyQt5.QtCore.QObject
#  |      sip.wrapper
#  |      PyQt5.QtGui.QPaintDevice
#  |      sip.simplewrapper
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  actionEvent(...)
#  |
#  |  cellActivated = <unbound PYQT_SIGNAL cellActivated(int,int)>
#  |  cellChanged = <unbound PYQT_SIGNAL cellChanged(int,int)>
#  |  cellClicked = <unbound PYQT_SIGNAL cellClicked(int,int)>
#  |  cellDoubleClicked = <unbound PYQT_SIGNAL cellDoubleClicked(int,int)>
#  |  cellEntered = <unbound PYQT_SIGNAL cellEntered(int,int)>
#  |  cellPressed = <unbound PYQT_SIGNAL cellPressed(int,int)>
#  |  cellWidget(...)
# ...

# %%
a = {0:"hi"}
a.keys()
# Out:
# dict_keys([0])

# %%
if 1 not in a.keys():
    print(True)
# Out:
# True

# %%
from sympy import *
x, y = symbols('x y')
f = sympify('sin(x)*a')

# %%
Symbol('x') in f.free_symbols
# Out:
# True
